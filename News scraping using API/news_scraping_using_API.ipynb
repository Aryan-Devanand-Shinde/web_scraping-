# %% [markdown]
# News Scraping using API

# %%
import requests as rq
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
API_KEY = "b4d4760e-8b72-4c6e-a7f4-973984c93d60"

# %%
url = f"https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&page=1&type=article&api-key={API_KEY}"

# %%
url_list=[]
for i in range(1,12):
    b=str(i)
    a=f"https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&page={b}&type=article&api-key={API_KEY}"
    url_list.append(a)
url_list
# Out:
# ['https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&page=1&type=article&api-key=b4d4760e-8b72-4c6e-a7f4-973984c93d60',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&page=2&type=article&api-key=b4d4760e-8b72-4c6e-a7f4-973984c93d60',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&page=3&type=article&api-key=b4d4760e-8b72-4c6e-a7f4-973984c93d60',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&page=4&type=article&api-key=b4d4760e-8b72-4c6e-a7f4-973984c93d60',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&page=5&type=article&api-key=b4d4760e-8b72-4c6e-a7f4-973984c93d60',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&page=6&type=article&api-key=b4d4760e-8b72-4c6e-a7f4-973984c93d60',
# ...

# %%
info = []

# %%
# loading the url
def json(url1):
    web = rq.get(url1)
    x = web.json()
    info.append(x)

# %%
output = [json(url1) for url1 in url_list]
info
# Out:
# [{'response': {'status': 'ok',
#    'userTier': 'developer',
#    'total': 254,
#    'startIndex': 1,
#    'pageSize': 10,
#    'currentPage': 1,
#    'pages': 26,
#    'orderBy': 'newest',
#    'tag': {'id': 'world/narendra-modi',
#     'type': 'keyword',
#     'sectionId': 'world',
#     'sectionName': 'World news',
#     'webTitle': 'Narendra Modi',
#     'webUrl': 'https://www.theguardian.com/world/narendra-modi',
#     'apiUrl': 'https://content.guardianapis.com/world/narendra-modi'},
#    'results': [{'id': 'world/2024/sep/14/hi-tech-strategic-new-wave-of-kashmir-militant-attacks-before-elections-stuns-indian-forces',
#      'type': 'article',
#      'sectionId': 'world',
#      'sectionName': 'World news',
#      'webPublicationDate': '2024-09-14T12:00:27Z',
#      'webTitle': 'Hi-tech, strategic: new wave of Kashmir militant attacks before elections stuns Indian forces',
# ...

# %%
info[0]['response']['results'][9]['webTitle'] # pageno.[0]
# Out:
# 'Modi and Putin cement ‘bonds of friendship’ despite Ukraine tensions'

# %%
try:
    finallist=[]
    for k in range(0,11):
        for j in range(0,10):
            value = dict(webtitle=info[k]['response']['results'][j]['webTitle'],
            sectionname = info[k]['response']['results'][j]['sectionName'],
            published_date=info[k]['response']['results'][j]['webPublicationDate'])
            finallist.append(value)
except IndexError:
    print('done')

# %%
finallist
# Out:
# [{'webtitle': 'Hi-tech, strategic: new wave of Kashmir militant attacks before elections stuns Indian forces',
#   'sectionname': 'World news',
#   'published_date': '2024-09-14T12:00:27Z'},
#  {'webtitle': 'These 21st-century demagogues aren’t mavericks – they’ve repeated on us throughout history | George Monbiot',
#   'sectionname': 'Opinion',
#   'published_date': '2024-09-06T05:00:17Z'},
#  {'webtitle': 'Why fascists hate universities | Jason Stanley',
#   'sectionname': 'Opinion',
#   'published_date': '2024-09-05T17:00:01Z'},
#  {'webtitle': 'Farming the Revolution review – low-key look at Indian farmers’ street-camp protests',
#   'sectionname': 'Film',
#   'published_date': '2024-08-26T12:00:31Z'},
#  {'webtitle': 'Ukraine war briefing: Biden and Zelenskiy talk as Ukraine prepares to mark independence day',
#   'sectionname': 'World news',
#   'published_date': '2024-08-24T05:09:29Z'},
#  {'webtitle': 'Five of the best books about Indian politics',
# ...

# %%
df = pd.DataFrame(finallist)
df
# Out:
#                                               webtitle sectionname  \
# 0    Hi-tech, strategic: new wave of Kashmir milita...  World news
# 1    These 21st-century demagogues aren’t mavericks...     Opinion
# 2       Why fascists hate universities | Jason Stanley     Opinion
# 3    Farming the Revolution review – low-key look a...        Film
# 4    Ukraine war briefing: Biden and Zelenskiy talk...  World news
# ..                                                 ...         ...
# 105  Opposition leader Rahul Gandhi begins two-day ...  World news
# 106  Amid the battle of the giants, a new global or...     Opinion
# 107  Modi’s US visit prompts condemnation and prote...  World news
# 108  Biden announces raft of new deals with Modi am...     US news
# 109  Modi’s visit focuses attention on caste discri...     US news
#
#            published_date
# 0    2024-09-14T12:00:27Z
# 1    2024-09-06T05:00:17Z
# 2    2024-09-05T17:00:01Z
# 3    2024-08-26T12:00:31Z
# ...
